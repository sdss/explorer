# %%
import vaex as vx
import plotly.express as px
from plotly.graph_objs._figurewidget import FigureWidget
import numpy as np

df = vx.example()  # Heelmi & de Zeeuw, 2000
z = df.count(binby=(df.x, df.y), shape=100, array_type="xarray")
z = np.log10(z)
z
# Out:
# /home/riley/Projects/visboard/.venv/lib/python3.10/site-packages/xarray/core/computation.py:825: RuntimeWarning:
#
# divide by zero encountered in log10
# <xarray.DataArray (x: 100, y: 100)> Size: 80kB
# array([[-inf, -inf, -inf, ..., -inf,   0., -inf],
#        [-inf, -inf, -inf, ..., -inf, -inf, -inf],
#        [-inf, -inf, -inf, ..., -inf, -inf, -inf],
#        ...,
#        [-inf, -inf, -inf, ..., -inf, -inf, -inf],
#        [-inf, -inf, -inf, ..., -inf, -inf, -inf],
#        [-inf, -inf, -inf, ..., -inf, -inf, -inf]])
# Coordinates:
#   * x        (x) float64 800B -77.09 -75.0 -72.92 -70.83 ... 125.3 127.4 129.5
#   * y        (y) float64 800B -171.8 -169.4 -167.1 -164.8 ... 54.2 56.53 58.86

# %% [markdown]
# Works fine for standard Figure object.

# %%
fig = px.imshow(z.T)
fig.update_xaxes(autorange="reversed")

# %%
fig.update_xaxes(autorange=True)

# %% [markdown]
# Now, trying with FigureWidget.

# %%
fig_widget = FigureWidget(fig)
fig_widget.update_xaxes(autorange="reversed")
# Out:
# /home/riley/Projects/visboard/.venv/lib/python3.10/site-packages/jupyter_client/session.py:721: UserWarning:
#
# Message serialization failed with:
# Out of range float values are not JSON compliant
# Supporting this message is deprecated in jupyter-client 7, please make sure your message is JSON-compliant
# FigureWidget({
#     'data': [{'coloraxis': 'coloraxis',
#               'hovertemplate': 'x: %{x}<br>y: %{y}<br>color: %{z}<extra></extra>',
#               'name': '0',
#               'type': 'heatmap',
#               'uid': '9a2669e9-0fa7-43fd-82e0-16b1cb0b79b5',
#               'x': array([-7.70898734e+01, -7.50035680e+01, -7.29172626e+01, -7.08309573e+01,
#                           -6.87446519e+01, -6.66583465e+01, -6.45720411e+01, -6.24857357e+01,
#                           -6.03994303e+01, -5.83131249e+01, -5.62268195e+01, -5.41405141e+01,
#                           -5.20542088e+01, -4.99679034e+01, -4.78815980e+01, -4.57952926e+01,
#                           -4.37089872e+01, -4.16226818e+01, -3.95363764e+01, -3.74500710e+01,
#                           -3.53637656e+01, -3.32774603e+01, -3.11911549e+01, -2.91048495e+01,
#                           -2.70185441e+01, -2.49322387e+01, -2.28459333e+01, -2.07596279e+01,
#                           -1.86733225e+01, -1.65870171e+01, -1.45007117e+01, -1.24144064e+01,
#                           -1.03281010e+01, -8.24179558e+00, -6.15549019e+00, -4.06918480e+00,
#                           -1.98287941e+00,  1.03425980e-01,  2.18973137e+00,  4.27603676e+00,
#                            6.36234215e+00,  8.44864754e+00,  1.05349529e+01,  1.26212583e+01,
#                            1.47075637e+01,  1.67938691e+01,  1.88801745e+01,  2.09664799e+01,
#                            2.30527853e+01,  2.51390907e+01,  2.72253960e+01,  2.93117014e+01,
#                            3.13980068e+01,  3.34843122e+01,  3.55706176e+01,  3.76569230e+01,
#                            3.97432284e+01,  4.18295338e+01,  4.39158392e+01,  4.60021445e+01,
#                            4.80884499e+01,  5.01747553e+01,  5.22610607e+01,  5.43473661e+01,
#                            5.64336715e+01,  5.85199769e+01,  6.06062823e+01,  6.26925877e+01,
#                            6.47788931e+01,  6.68651984e+01,  6.89515038e+01,  7.10378092e+01,
#                            7.31241146e+01,  7.52104200e+01,  7.72967254e+01,  7.93830308e+01,
#                            8.14693362e+01,  8.35556416e+01,  8.56419469e+01,  8.77282523e+01,
#                            8.98145577e+01,  9.19008631e+01,  9.39871685e+01,  9.60734739e+01,
#                            9.81597793e+01,  1.00246085e+02,  1.02332390e+02,  1.04418695e+02,
#                            1.06505001e+02,  1.08591306e+02,  1.10677612e+02,  1.12763917e+02,
#                            1.14850222e+02,  1.16936528e+02,  1.19022833e+02,  1.21109139e+02,
#                            1.23195444e+02,  1.25281749e+02,  1.27368055e+02,  1.29454360e+02]),
#               'xaxis': 'x',
#               'y': array([-171.77889305, -169.44922802, -167.11956299, -164.78989796,
#                           -162.46023293, -160.1305679 , -157.80090286, -155.47123783,
#                           -153.1415728 , -150.81190777, -148.48224274, -146.15257771,
#                           -143.82291268, -141.49324765, -139.16358262, -136.83391759,
#                           -134.50425255, -132.17458752, -129.84492249, -127.51525746,
#                           -125.18559243, -122.8559274 , -120.52626237, -118.19659734,
#                           -115.86693231, -113.53726727, -111.20760224, -108.87793721,
#                           -106.54827218, -104.21860715, -101.88894212,  -99.55927709,
#                            -97.22961206,  -94.89994703,  -92.570282  ,  -90.24061696,
#                            -87.91095193,  -85.5812869 ,  -83.25162187,  -80.92195684,
#                            -78.59229181,  -76.26262678,  -73.93296175,  -71.60329672,
#                            -69.27363169,  -66.94396665,  -64.61430162,  -62.28463659,
#                            -59.95497156,  -57.62530653,  -55.2956415 ,  -52.96597647,
#                            -50.63631144,  -48.30664641,  -45.97698137,  -43.64731634,
#                            -41.31765131,  -38.98798628,  -36.65832125,  -34.32865622,
#                            -31.99899119,  -29.66932616,  -27.33966113,  -25.0099961 ,
#                            -22.68033106,  -20.35066603,  -18.021001  ,  -15.69133597,
#                            -13.36167094,  -11.03200591,   -8.70234088,   -6.37267585,
#                             -4.04301082,   -1.71334578,    0.61631925,    2.94598428,
#                              5.27564931,    7.60531434,    9.93497937,   12.2646444 ,
#                             14.59430943,   16.92397446,   19.25363949,   21.58330453,
#                             23.91296956,   26.24263459,   28.57229962,   30.90196465,
#                             33.23162968,   35.56129471,   37.89095974,   40.22062477,
#                             42.55028981,   44.87995484,   47.20961987,   49.5392849 ,
#                             51.86894993,   54.19861496,   56.52827999,   58.85794502]),
#               'yaxis': 'y',
#               'z': array([[-inf, -inf, -inf, ..., -inf, -inf, -inf],
#                           [-inf, -inf, -inf, ..., -inf, -inf, -inf],
#                           [-inf, -inf, -inf, ..., -inf, -inf, -inf],
#                           ...,
#                           [-inf, -inf, -inf, ..., -inf, -inf, -inf],
#                           [  0., -inf, -inf, ..., -inf, -inf, -inf],
#                           [-inf, -inf, -inf, ..., -inf, -inf, -inf]])}],
#     'layout': {'coloraxis': {'colorscale': [[0.0, '#0d0887'], [0.1111111111111111,
#                                             '#46039f'], [0.2222222222222222,
#                                             '#7201a8'], [0.3333333333333333,
#                                             '#9c179e'], [0.4444444444444444,
#                                             '#bd3786'], [0.5555555555555556,
#                                             '#d8576b'], [0.6666666666666666,
#                                             '#ed7953'], [0.7777777777777778,
#                                             '#fb9f3a'], [0.8888888888888888,
#                                             '#fdca26'], [1.0, '#f0f921']]},
#                'margin': {'t': 60},
#                'template': '...',
#                'xaxis': {'anchor': 'y', 'autorange': 'reversed', 'domain': [0.0, 1.0], 'title': {'text': 'x'}},
#                'yaxis': {'anchor': 'x', 'autorange': 'reversed', 'domain': [0.0, 1.0], 'title': {'text': 'y'}}}
# })

# %%
fig_widget.update_xaxes(autorange=True)
# Out:
# FigureWidget({
#     'data': [{'coloraxis': 'coloraxis',
#               'hovertemplate': 'x: %{x}<br>y: %{y}<br>color: %{z}<extra></extra>',
#               'name': '0',
#               'type': 'heatmap',
#               'uid': '9a2669e9-0fa7-43fd-82e0-16b1cb0b79b5',
#               'x': array([-7.70898734e+01, -7.50035680e+01, -7.29172626e+01, -7.08309573e+01,
#                           -6.87446519e+01, -6.66583465e+01, -6.45720411e+01, -6.24857357e+01,
#                           -6.03994303e+01, -5.83131249e+01, -5.62268195e+01, -5.41405141e+01,
#                           -5.20542088e+01, -4.99679034e+01, -4.78815980e+01, -4.57952926e+01,
#                           -4.37089872e+01, -4.16226818e+01, -3.95363764e+01, -3.74500710e+01,
#                           -3.53637656e+01, -3.32774603e+01, -3.11911549e+01, -2.91048495e+01,
#                           -2.70185441e+01, -2.49322387e+01, -2.28459333e+01, -2.07596279e+01,
#                           -1.86733225e+01, -1.65870171e+01, -1.45007117e+01, -1.24144064e+01,
#                           -1.03281010e+01, -8.24179558e+00, -6.15549019e+00, -4.06918480e+00,
#                           -1.98287941e+00,  1.03425980e-01,  2.18973137e+00,  4.27603676e+00,
#                            6.36234215e+00,  8.44864754e+00,  1.05349529e+01,  1.26212583e+01,
#                            1.47075637e+01,  1.67938691e+01,  1.88801745e+01,  2.09664799e+01,
#                            2.30527853e+01,  2.51390907e+01,  2.72253960e+01,  2.93117014e+01,
#                            3.13980068e+01,  3.34843122e+01,  3.55706176e+01,  3.76569230e+01,
#                            3.97432284e+01,  4.18295338e+01,  4.39158392e+01,  4.60021445e+01,
#                            4.80884499e+01,  5.01747553e+01,  5.22610607e+01,  5.43473661e+01,
#                            5.64336715e+01,  5.85199769e+01,  6.06062823e+01,  6.26925877e+01,
#                            6.47788931e+01,  6.68651984e+01,  6.89515038e+01,  7.10378092e+01,
#                            7.31241146e+01,  7.52104200e+01,  7.72967254e+01,  7.93830308e+01,
#                            8.14693362e+01,  8.35556416e+01,  8.56419469e+01,  8.77282523e+01,
#                            8.98145577e+01,  9.19008631e+01,  9.39871685e+01,  9.60734739e+01,
#                            9.81597793e+01,  1.00246085e+02,  1.02332390e+02,  1.04418695e+02,
#                            1.06505001e+02,  1.08591306e+02,  1.10677612e+02,  1.12763917e+02,
#                            1.14850222e+02,  1.16936528e+02,  1.19022833e+02,  1.21109139e+02,
#                            1.23195444e+02,  1.25281749e+02,  1.27368055e+02,  1.29454360e+02]),
#               'xaxis': 'x',
#               'y': array([-171.77889305, -169.44922802, -167.11956299, -164.78989796,
#                           -162.46023293, -160.1305679 , -157.80090286, -155.47123783,
#                           -153.1415728 , -150.81190777, -148.48224274, -146.15257771,
#                           -143.82291268, -141.49324765, -139.16358262, -136.83391759,
#                           -134.50425255, -132.17458752, -129.84492249, -127.51525746,
#                           -125.18559243, -122.8559274 , -120.52626237, -118.19659734,
#                           -115.86693231, -113.53726727, -111.20760224, -108.87793721,
#                           -106.54827218, -104.21860715, -101.88894212,  -99.55927709,
#                            -97.22961206,  -94.89994703,  -92.570282  ,  -90.24061696,
#                            -87.91095193,  -85.5812869 ,  -83.25162187,  -80.92195684,
#                            -78.59229181,  -76.26262678,  -73.93296175,  -71.60329672,
#                            -69.27363169,  -66.94396665,  -64.61430162,  -62.28463659,
#                            -59.95497156,  -57.62530653,  -55.2956415 ,  -52.96597647,
#                            -50.63631144,  -48.30664641,  -45.97698137,  -43.64731634,
#                            -41.31765131,  -38.98798628,  -36.65832125,  -34.32865622,
#                            -31.99899119,  -29.66932616,  -27.33966113,  -25.0099961 ,
#                            -22.68033106,  -20.35066603,  -18.021001  ,  -15.69133597,
#                            -13.36167094,  -11.03200591,   -8.70234088,   -6.37267585,
#                             -4.04301082,   -1.71334578,    0.61631925,    2.94598428,
#                              5.27564931,    7.60531434,    9.93497937,   12.2646444 ,
#                             14.59430943,   16.92397446,   19.25363949,   21.58330453,
#                             23.91296956,   26.24263459,   28.57229962,   30.90196465,
#                             33.23162968,   35.56129471,   37.89095974,   40.22062477,
#                             42.55028981,   44.87995484,   47.20961987,   49.5392849 ,
#                             51.86894993,   54.19861496,   56.52827999,   58.85794502]),
#               'yaxis': 'y',
#               'z': array([[-inf, -inf, -inf, ..., -inf, -inf, -inf],
#                           [-inf, -inf, -inf, ..., -inf, -inf, -inf],
#                           [-inf, -inf, -inf, ..., -inf, -inf, -inf],
#                           ...,
#                           [-inf, -inf, -inf, ..., -inf, -inf, -inf],
#                           [  0., -inf, -inf, ..., -inf, -inf, -inf],
#                           [-inf, -inf, -inf, ..., -inf, -inf, -inf]])}],
#     'layout': {'coloraxis': {'colorscale': [[0.0, '#0d0887'], [0.1111111111111111,
#                                             '#46039f'], [0.2222222222222222,
#                                             '#7201a8'], [0.3333333333333333,
#                                             '#9c179e'], [0.4444444444444444,
#                                             '#bd3786'], [0.5555555555555556,
#                                             '#d8576b'], [0.6666666666666666,
#                                             '#ed7953'], [0.7777777777777778,
#                                             '#fb9f3a'], [0.8888888888888888,
#                                             '#fdca26'], [1.0, '#f0f921']]},
#                'margin': {'t': 60},
#                'template': '...',
#                'xaxis': {'anchor': 'y', 'autorange': True, 'domain': [0.0, 1.0], 'title': {'text': 'x'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'y'}}}
# })

# %%
print(fig_widget.layout.xaxis)
# Out:
# layout.XAxis({
#     'anchor': 'y', 'autorange': True, 'domain': [0.0, 1.0], 'title': {'text': 'x'}
# })
